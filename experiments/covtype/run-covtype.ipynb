# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Covertype balanced: Lodgepole vs. all

# %%
from experiment_runner import run_all
from params import gen_params_list
from util import average_results

data_bal_h5 = "covtype-lodgepole-vs-rest.h5"
data_unbal_h5 = "covtype-broadleaf-vs-rest.h5"

df = pd.read_hdf(data_bal_h5)
catfeats = list(range(10, 53+1))
df.iloc[:, catfeats] = df.iloc[:, catfeats].astype(np.int32) #.astype('category')

# %% [markdown]
# ## Accurate parameter set (bal)
#
# Note that these numbers do not correspond exactly to the numbers in the paper as they were generated by a different machine. The general conclusions are unchanged, however.

# %%
params_list = gen_params_list({
    "method": ["bit", "lgb", "xgb", "cat"],
    "target": "Cover_Type",
    "categorical": [catfeats],
    "learning_rate": 0.2,
    "objective": "binary", "metric": "error",
    "niterations": [200], "max_depth": [6],
    "example_fraction": [1.0],
    "feature_fraction": [0.8],
    "bit_discr_nbits": [8],
    "bit_sample_freq": [20],
    "bit_max_nbins": [16]
})

csv = run_all(df, params_list, nprocs=4, random_state=5564)
# Out:
# [pid=26643] 14:24:54 bit fold 1/5
# [pid=26644] 14:24:54 lgb fold 1/5
# [pid=26651] 14:24:55 xgb fold 1/5
# [pid=26652] 14:24:55 cat fold 1/5
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [pid=26643] 14:25:40 bit fold 2/5
# [pid=26644] 14:25:50 lgb fold 2/5
# [pid=26651] 14:25:51 xgb fold 2/5
# [pid=26643] 14:26:26 bit fold 3/5
# [pid=26644] 14:26:45 lgb fold 3/5
# [pid=26651] 14:26:45 xgb fold 3/5
# [pid=26652] 14:27:04 cat fold 2/5
# [pid=26643] 14:27:08 bit fold 4/5
# [pid=26651] 14:27:39 xgb fold 4/5
# [pid=26644] 14:27:40 lgb fold 4/5
# [pid=26643] 14:27:55 bit fold 5/5
# [pid=26651] 14:28:33 xgb fold 5/5
# [pid=26644] 14:28:34 lgb fold 5/5
# [pid=26643] 14:28:37 bit done
# [pid=26652] 14:29:09 cat fold 3/5
# [pid=26651] 14:29:22 xgb done
# [pid=26644] 14:29:25 lgb done
# [pid=26652] 14:31:02 cat fold 4/5
# [pid=26652] 14:32:57 cat fold 5/5
# [pid=26652] 14:34:47 cat done

# %%
average_results(csv)
# Out:
#                      (method, first) (objective, first)  \
# hash
# -1790270010335601920             bit             binary
# -3359913233184512792             cat             binary
# -5678132391703079018             lgb             binary
# -4593058943157956156             xgb             binary
#
#                       (learning_rate, first)  (feature_fraction, first)  \
# hash
# -1790270010335601920                     0.2                        0.8
# -3359913233184512792                     0.2                        0.8
# -5678132391703079018                     0.2                        0.8
# -4593058943157956156                     0.2                        0.8
#
#                       (example_fraction, first)  (max_depth, first)  \
# hash
# -1790270010335601920                        1.0                   6
# -3359913233184512792                        1.0                   6
# -5678132391703079018                        1.0                   6
# -4593058943157956156                        1.0                   6
#
#                       (niterations, first)  (bit_sample_freq, first)  \
# hash
# -1790270010335601920                   200                        20
# -3359913233184512792                   200                         1
# -5678132391703079018                   200                         1
# -4593058943157956156                   200                         1
#
#                       (bit_discr_nbits, first)  (bit_compr_threshold, first)  \
# hash
# -1790270010335601920                         8                           0.5
# -3359913233184512792                         4                           0.5
# -5678132391703079018                         4                           0.5
# -4593058943157956156                         4                           0.5
#
#                       (bit_max_nbins, first)  (train_time, mean)  \
# hash
# -1790270010335601920                      16           16.420584
# -3359913233184512792                      16           55.129584
# -5678132391703079018                      16           22.793584
# -4593058943157956156                      16           24.989158
#
#                       (train_time, std)  (metric_train, mean)  \
# hash
# -1790270010335601920           1.244623              0.112756
# -3359913233184512792           3.481779              0.129898
# -5678132391703079018           1.811810              0.118716
# -4593058943157956156           2.366028              0.107134
#
#                       (metric_train, std)  (metric_val, mean)  \
# hash
# -1790270010335601920             0.001814            0.117250
# -3359913233184512792             0.000509            0.132314
# -5678132391703079018             0.001909            0.125124
# -4593058943157956156             0.001049            0.113354
#
#                       (metric_val, std)  (metric_test, mean)  \
# hash
# -1790270010335601920           0.001923             0.117104
# -3359913233184512792           0.000923             0.132734
# -5678132391703079018           0.001727             0.123508
# -4593058943157956156           0.001594             0.113396
#
#                       (metric_test, std)  count
# hash
# -1790270010335601920            0.001961      5
# -3359913233184512792            0.000907      5
# -5678132391703079018            0.001990      5
# -4593058943157956156            0.001586      5

# %% [markdown]
# ## Fast parameter set (bal)

# %%
params_list = gen_params_list({
    "method": ["bit", "xgb", "lgb", "cat"],
    "target": "Cover_Type",
    "categorical": [catfeats],
    "learning_rate": 0.2,
    "objective": "binary", "metric": "error",
    "niterations": [200], "max_depth": [6],
    "example_fraction": [0.2],
    "feature_fraction": [0.5],
    "bit_discr_nbits": [8],
    "bit_sample_freq": [20],
    "bit_max_nbins": [16]
})

csv = run_all(df, params_list, nprocs=4, random_state=5564)
# Out:
# [pid=29999] 15:44:28 bit fold 1/5
# [pid=30000] 15:44:29 xgb fold 1/5
# [pid=30001] 15:44:29 lgb fold 1/5
# [pid=30002] 15:44:29 cat fold 1/5
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [pid=29999] 15:44:46 bit fold 2/5
# [pid=29999] 15:45:02 bit fold 3/5
# [pid=30001] 15:45:03 lgb fold 2/5
# [pid=29999] 15:45:17 bit fold 4/5
# [pid=29999] 15:45:33 bit fold 5/5
# [pid=30001] 15:45:37 lgb fold 3/5
# [pid=30000] 15:45:45 xgb fold 2/5
# [pid=29999] 15:45:48 bit done
# [pid=30002] 15:46:07 cat fold 2/5
# [pid=30001] 15:46:10 lgb fold 4/5
# [pid=30001] 15:46:42 lgb fold 5/5
# [pid=30000] 15:46:56 xgb fold 3/5
# [pid=30001] 15:47:14 lgb done
# [pid=30002] 15:47:36 cat fold 3/5
# [pid=30000] 15:48:05 xgb fold 4/5
# [pid=30002] 15:49:02 cat fold 4/5
# [pid=30000] 15:49:14 xgb fold 5/5
# [pid=30000] 15:50:23 xgb done
# [pid=30002] 15:50:28 cat fold 5/5
# [pid=30002] 15:51:51 cat done

# %%
average_results(csv)
# Out:
#                      (method, first) (objective, first)  \
# hash
#  3593934032320450165             bit             binary
#  5068698494584965138             cat             binary
# -5184146974060491343             lgb             binary
#  537854442106002861              xgb             binary
#
#                       (learning_rate, first)  (feature_fraction, first)  \
# hash
#  3593934032320450165                     0.2                        0.5
#  5068698494584965138                     0.2                        0.5
# -5184146974060491343                     0.2                        0.5
#  537854442106002861                      0.2                        0.5
#
#                       (example_fraction, first)  (max_depth, first)  \
# hash
#  3593934032320450165                        0.2                   6
#  5068698494584965138                        0.2                   6
# -5184146974060491343                        0.2                   6
#  537854442106002861                         0.2                   6
#
#                       (niterations, first)  (bit_sample_freq, first)  \
# hash
#  3593934032320450165                   200                        20
#  5068698494584965138                   200                         1
# -5184146974060491343                   200                         1
#  537854442106002861                    200                         1
#
#                       (bit_discr_nbits, first)  (bit_compr_threshold, first)  \
# hash
#  3593934032320450165                         8                           0.5
#  5068698494584965138                         4                           0.5
# -5184146974060491343                         4                           0.5
#  537854442106002861                          4                           0.5
#
#                       (bit_max_nbins, first)  (train_time, mean)  \
# hash
#  3593934032320450165                      16            4.776640
#  5068698494584965138                      16           39.567678
# -5184146974060491343                      16            9.744244
#  537854442106002861                       16           36.208198
#
#                       (train_time, std)  (metric_train, mean)  \
# hash
#  3593934032320450165           0.531404              0.145904
#  5068698494584965138           2.582815              0.137698
# -5184146974060491343           0.273957              0.125002
#  537854442106002861            1.288155              0.113302
#
#                       (metric_train, std)  (metric_val, mean)  \
# hash
#  3593934032320450165             0.003046            0.139458
#  5068698494584965138             0.000977            0.139930
# -5184146974060491343             0.001393            0.131224
#  537854442106002861              0.000953            0.120998
#
#                       (metric_val, std)  (metric_test, mean)  \
# hash
#  3593934032320450165           0.004853             0.149270
#  5068698494584965138           0.000790             0.140198
# -5184146974060491343           0.000967             0.129632
#  537854442106002861            0.001506             0.119244
#
#                       (metric_test, std)  count
# hash
#  3593934032320450165            0.002709      5
#  5068698494584965138            0.001204      5
# -5184146974060491343            0.001107      5
#  537854442106002861             0.000959      5

# %% [markdown]
# # Covertype unbalanced: Broadleaf vs. all

# %%
dfu = pd.read_hdf(data_unbal_h5)
dfu.iloc[:, catfeats] = dfu.iloc[:, catfeats].astype(np.int32) #.astype('category')

# %%
dfu["Cover_Type"].sum() / len(dfu)
# Out:
# 0.021066690533069886

# %% [markdown]
# ## Accurate parameter set (unbal)
#
# Note that these numbers do not correspond exactly to the numbers in the paper as they were generated by a different machine. The general conclusions are unchanged, however.

# %%
params_list = gen_params_list({
    "method": ["bit", "lgb", "xgb", "cat"],
    "target": "Cover_Type",
    "categorical": [catfeats],
    "learning_rate": 0.2,
    "objective": "binary", "metric": "error",
    "niterations": [200], "max_depth": [6],
    "example_fraction": [0.5],
    "feature_fraction": [1.0],
    "bit_discr_nbits": [8],
    "bit_sample_freq": [20],
    "bit_max_nbins": [16]
})

csv = run_all(dfu, params_list, nprocs=4, random_state=5564)
# Out:
# [pid=31020] 16:30:20 bit fold 1/5
# [pid=31021] 16:30:21 lgb fold 1/5
# [pid=31022] 16:30:21 xgb fold 1/5
# [pid=31023] 16:30:21 cat fold 1/5
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [pid=31020] 16:30:52 bit fold 2/5
# [pid=31021] 16:31:19 lgb fold 2/5
# [pid=31020] 16:31:20 bit fold 3/5
# [pid=31020] 16:31:48 bit fold 4/5
# [pid=31022] 16:31:53 xgb fold 2/5
# [pid=31023] 16:32:12 cat fold 2/5
# [pid=31021] 16:32:14 lgb fold 3/5
# [pid=31020] 16:32:17 bit fold 5/5
# [pid=31020] 16:32:45 bit done
# [pid=31021] 16:33:08 lgb fold 4/5
# [pid=31022] 16:33:19 xgb fold 3/5
# [pid=31023] 16:33:53 cat fold 3/5
# [pid=31021] 16:34:01 lgb fold 5/5
# Training has stopped (degenerate solution on iteration 197, probably too small l2-regularization, try to increase it)
# [pid=31022] 16:34:40 xgb fold 4/5
# [pid=31021] 16:34:52 lgb done
# [pid=31023] 16:35:25 cat fold 4/5
# [pid=31022] 16:35:57 xgb fold 5/5
# [pid=31023] 16:36:57 cat fold 5/5
# [pid=31022] 16:37:20 xgb done
# [pid=31023] 16:38:32 cat done

# %%
average_results(csv)
# Out:
#                      (method, first) (objective, first)  \
# hash
#  6448386558530219552             bit             binary
#  1394181712130597728             cat             binary
# -1627785957177796703             lgb             binary
#  331481379124971174              xgb             binary
#
#                       (learning_rate, first)  (feature_fraction, first)  \
# hash
#  6448386558530219552                     0.2                        1.0
#  1394181712130597728                     0.2                        1.0
# -1627785957177796703                     0.2                        1.0
#  331481379124971174                      0.2                        1.0
#
#                       (example_fraction, first)  (max_depth, first)  \
# hash
#  6448386558530219552                        0.5                   6
#  1394181712130597728                        0.5                   6
# -1627785957177796703                        0.5                   6
#  331481379124971174                         0.5                   6
#
#                       (niterations, first)  (bit_sample_freq, first)  \
# hash
#  6448386558530219552                   200                        20
#  1394181712130597728                   200                         1
# -1627785957177796703                   200                         1
#  331481379124971174                    200                         1
#
#                       (bit_discr_nbits, first)  (bit_compr_threshold, first)  \
# hash
#  6448386558530219552                         8                           0.5
#  1394181712130597728                         4                           0.5
# -1627785957177796703                         4                           0.5
#  331481379124971174                          4                           0.5
#
#                       (bit_max_nbins, first)  (train_time, mean)  \
# hash
#  6448386558530219552                      16           10.686544
#  1394181712130597728                      16           43.247254
# -1627785957177796703                      16           20.913010
#  331481379124971174                       16           41.873512
#
#                       (train_time, std)  (metric_train, mean)  \
# hash
#  6448386558530219552           0.676454              0.005394
#  1394181712130597728           4.039260              0.007774
# -1627785957177796703           1.041148              0.004318
#  331481379124971174            2.169241              0.003800
#
#                       (metric_train, std)  (metric_val, mean)  \
# hash
#  6448386558530219552             0.000355            0.008062
#  1394181712130597728             0.000229            0.009276
# -1627785957177796703             0.000064            0.007366
#  331481379124971174              0.000135            0.006750
#
#                       (metric_val, std)  (metric_test, mean)  \
# hash
#  6448386558530219552           0.000263             0.007994
#  1394181712130597728           0.000358             0.009058
# -1627785957177796703           0.000209             0.006918
#  331481379124971174            0.000358             0.006240
#
#                       (metric_test, std)  count
# hash
#  6448386558530219552            0.000461      5
#  1394181712130597728            0.000295      5
# -1627785957177796703            0.000230      5
#  331481379124971174             0.000198      5

# %% [markdown]
# ## Fast parameter set (unbal)

# %%
params_list = gen_params_list({
    "method": ["bit", "xgb"],
    "target": "Cover_Type",
    "categorical": [catfeats],
    "learning_rate": 0.15,
    "objective": "hinge", "metric": "error",
    "niterations": [200], "max_depth": [6],
    "example_fraction": [0.5],
    "feature_fraction": [1.0],
    "bit_discr_nbits": [2],
    "bit_sample_freq": [20],
    "bit_max_nbins": [16]
}) + gen_params_list({
    "method": ["lgb", "cat"],
    "target": "Cover_Type",
    "categorical": [catfeats],
    "learning_rate": 0.15,
    "objective": "binary", "metric": "error",
    "niterations": [200], "max_depth": [6],
    "example_fraction": [0.5],
    "feature_fraction": [1.0],
})

csv = run_all(dfu, params_list, nprocs=4, random_state=5564)
# Out:
# [pid=31445] 16:38:33 bit fold 1/5
# [pid=31446] 16:38:33 xgb fold 1/5
# [pid=31447] 16:38:34 lgb fold 1/5
# [pid=31448] 16:38:34 cat fold 1/5
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/laurensd/.local/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [pid=31445] 16:38:59 bit fold 2/5
# [pid=31445] 16:39:22 bit fold 3/5
# [pid=31447] 16:39:31 lgb fold 2/5
# [pid=31445] 16:39:42 bit fold 4/5
# [pid=31446] 16:40:06 xgb fold 2/5
# [pid=31445] 16:40:06 bit fold 5/5
# [pid=31445] 16:40:27 bit done
# [pid=31447] 16:40:28 lgb fold 3/5
# [pid=31448] 16:40:29 cat fold 2/5
# [pid=31447] 16:41:21 lgb fold 4/5
# [pid=31446] 16:41:31 xgb fold 3/5
# [pid=31448] 16:42:12 cat fold 3/5
# [pid=31447] 16:42:16 lgb fold 5/5
# [pid=31446] 16:42:52 xgb fold 4/5
# [pid=31447] 16:43:09 lgb done
# [pid=31448] 16:43:49 cat fold 4/5
# [pid=31446] 16:44:09 xgb fold 5/5
# [pid=31448] 16:45:24 cat fold 5/5
# [pid=31446] 16:45:28 xgb done
# [pid=31448] 16:46:55 cat done

# %%
average_results(csv)
# Out:
#                      (method, first) (objective, first)  \
# hash
#  7108023381590875742             bit              hinge
# -1041551397726785313             cat             binary
# -7630976768326965643             lgb             binary
# -3369563745176989613             xgb              hinge
#
#                       (learning_rate, first)  (feature_fraction, first)  \
# hash
#  7108023381590875742                    0.15                        1.0
# -1041551397726785313                    0.15                        1.0
# -7630976768326965643                    0.15                        1.0
# -3369563745176989613                    0.15                        1.0
#
#                       (example_fraction, first)  (max_depth, first)  \
# hash
#  7108023381590875742                        0.5                   6
# -1041551397726785313                        0.5                   6
# -7630976768326965643                        0.5                   6
# -3369563745176989613                        0.5                   6
#
#                       (niterations, first)  (bit_sample_freq, first)  \
# hash
#  7108023381590875742                   200                        20
# -1041551397726785313                   200                         1
# -7630976768326965643                   200                         1
# -3369563745176989613                   200                         1
#
#                       (bit_discr_nbits, first)  (bit_compr_threshold, first)  \
# hash
#  7108023381590875742                         2                           0.5
# -1041551397726785313                         4                           0.5
# -7630976768326965643                         4                           0.5
# -3369563745176989613                         4                           0.5
#
#                       (bit_max_nbins, first)  (train_time, mean)  \
# hash
#  7108023381590875742                      16            8.021854
# -1041551397726785313                      16           45.355126
# -7630976768326965643                      16           21.676110
# -3369563745176989613                      16           41.756526
#
#                       (train_time, std)  (metric_train, mean)  \
# hash
#  7108023381590875742           0.957834              0.008750
# -1041551397726785313           5.189204              0.008976
# -7630976768326965643           1.307301              0.005588
# -3369563745176989613           2.652476              0.005094
#
#                       (metric_train, std)  (metric_val, mean)  \
# hash
#  7108023381590875742             0.002705            0.010142
# -1041551397726785313             0.000277            0.010222
# -7630976768326965643             0.000061            0.007820
# -3369563745176989613             0.000134            0.007518
#
#                       (metric_val, std)  (metric_test, mean)  \
# hash
#  7108023381590875742           0.002101             0.010036
# -1041551397726785313           0.000417             0.009940
# -7630976768326965643           0.000345             0.007528
# -3369563745176989613           0.000305             0.007060
#
#                       (metric_test, std)  count
# hash
#  7108023381590875742            0.002138      5
# -1041551397726785313            0.000214      5
# -7630976768326965643            0.000264      5
# -3369563745176989613            0.000229      5
